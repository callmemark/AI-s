# %%
import pandas as pd

# %%
data = pd.read_csv("Color_data.csv")
pd.set_option("display.max_rows", 117)
data
# Out:
#        R    G    B         Color name  Id
# 0     51    0    0          red-shade   1
# 1    102    0    0          red-shade   1
# 2    153    0    0          red-shade   1
# 3    204    0    0          red-shade   1
# 4    255    0    0          red-shade   1
# 5    255   51   51          red-shade   1
# 6    255  102  102          red-shade   1
# 7    255  153  153          red-shade   1
# 8    255  204  204          red-shade   1
# 9     51   25    0       orange-shade   2
# 10   102   51    0       orange-shade   2
# 11   153   76    0       orange-shade   2
# 12   204  102    0       orange-shade   2
# 13   255  128    0       orange-shade   2
# 14   255  153   51       orange-shade   2
# 15   255  178  102       orange-shade   2
# 16   255  204  153       orange-shade   2
# 17   255  209  204       orange-shade   2
# 18    51   51    0       yellow-shade   3
# 19   102  102    0       yellow-shade   3
# 20   153  153    0       yellow-shade   3
# 21   204  204    0       yellow-shade   3
# 22   255  255    0       yellow-shade   3
# 23   255  255   51       yellow-shade   3
# 24   255  255  102       yellow-shade   3
# 25   255  255  153       yellow-shade   3
# 26   255  255  204       yellow-shade   3
# 27    25   51    0  yellowgreen-shade   4
# 28    51  102    0  yellowgreen-shade   4
# 29    76  153    0  yellowgreen-shade   4
# 30   102  204    0  yellowgreen-shade   4
# 31   128  255    0  yellowgreen-shade   4
# 32   153  255   51  yellowgreen-shade   4
# 33   178  255  102  yellowgreen-shade   4
# 34   204  255  153  yellowgreen-shade   4
# 35   229  255  204  yellowgreen-shade   4
# 36     0   51    0        green-shade   5
# 37     0  102    0        green-shade   5
# 38     0  153    0        green-shade   5
# 39     0  204    0        green-shade   5
# 40     0  255    0        green-shade   5
# 41    51  255   51        green-shade   5
# 42   102  255  102        green-shade   5
# 43   153  255  153        green-shade   5
# 44   204  255  204        green-shade   5
# 45     0   51   25    bluegreen-shade   6
# 46     0  102   51    bluegreen-shade   6
# 47     0  153   76    bluegreen-shade   6
# 48     0  204  102    bluegreen-shade   6
# 49     0  255  128    bluegreen-shade   6
# 50    51  255  153    bluegreen-shade   6
# 51   102  255  178    bluegreen-shade   6
# 52   153  255  204    bluegreen-shade   6
# 53   204  255  229    bluegreen-shade   6
# 54     0   51   51         neon-shade   7
# 55     0  102  102         neon-shade   7
# 56     0  153  153         neon-shade   7
# 57     0  204  204         neon-shade   7
# 58     0  255  255         neon-shade   7
# 59    51  255  255         neon-shade   7
# 60   102  255  255         neon-shade   7
# 61   153  255  255         neon-shade   7
# 62   204  255  255         neon-shade   7
# 63     0   25   51    lightblue-shade   8
# 64     0   51  102    lightblue-shade   8
# 65     0   76  153    lightblue-shade   8
# 66     0  102  204    lightblue-shade   8
# 67     0  128  255    lightblue-shade   8
# 68    51  153  255    lightblue-shade   8
# 69   102  178  255    lightblue-shade   8
# 70   153  204  255    lightblue-shade   8
# 71   204  229  255    lightblue-shade   8
# 72     0    0   51         blue-shade   9
# 73     0    0  102         blue-shade   9
# 74     0    0  153         blue-shade   9
# 75     0    0  204         blue-shade   9
# 76     0    0  255         blue-shade   9
# 77    51   51  255         blue-shade   9
# 78   102  102  255         blue-shade   9
# 79   153  153  255         blue-shade   9
# 80   204  204  255         blue-shade   9
# 81    25    0   51    bluviolet-shade  10
# 82    51    0  102    bluviolet-shade  10
# 83    76    0  153    bluviolet-shade  10
# 84   102    0  204    bluviolet-shade  10
# 85   127    0  255    bluviolet-shade  10
# 86   153   51  255    bluviolet-shade  10
# 87   178  102  255    bluviolet-shade  10
# 88   204  153  255    bluviolet-shade  10
# 89   229  204  255    bluviolet-shade  10
# 90    51    0   51       violet-shade  11
# 91   102    0  102       violet-shade  11
# 92   153    0  153       violet-shade  11
# 93   204    0  204       violet-shade  11
# 94   255    0  255       violet-shade  11
# 95   255   51  255       violet-shade  11
# 96   255  102  255       violet-shade  11
# 97   255  153  255       violet-shade  11
# 98   255  204  255       violet-shade  11
# 99    51    0   25         pink-shade  12
# 100  102    0   51         pink-shade  12
# 101  153    0   76         pink-shade  12
# 102  204    0  102         pink-shade  12
# 103  255    0  127         pink-shade  12
# 104  255   51  153         pink-shade  12
# 105  255  102  178         pink-shade  12
# 106  255  153  204         pink-shade  12
# 107  255  204  229         pink-shade  12
# 108    0    0    0        black-shade  13
# 109   32   32   32        black-shade  13
# 110   64   64   64        black-shade  13
# 111   96   96   96        black-shade  13
# 112  128  128  128        black-shade  13
# 113  160  160  160        black-shade  13
# 114  192  192  192        black-shade  13
# 115  224  224  224        black-shade  13
# 116  255  255  255        black-shade  13

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
R = data["R"]
G = data["G"]
B = data["B"]

X = data.iloc[:, :-2].values
y = data["Id"]

# %%
model = KNeighborsClassifier(n_neighbors = 7)
model.fit(X, y)


input = [94, 108, 204]



prediction = model.predict([input])
print(prediction)


if prediction == [1]: print("red-shade")
if prediction == [2]: print("orange-shade")
if prediction == [3]: print("yellow-shade")
if prediction == [4]: print("yellowgreen-shade")
if prediction == [5]: print("green-shade")
if prediction == [6]: print("bluegreen-shade")
if prediction == [7]: print("neon-shade")
if prediction == [8]: print("lightblue-shade")
if prediction == [9]: print("blue-shade")
if prediction == [10]: print("bluviolet-shade")
if prediction == [11]: print("violet-shade")
if prediction == [12]: print("pink-shade")
if prediction == [13]: print("black-shade")
# Out:
# [8]
# lightblue-shade
